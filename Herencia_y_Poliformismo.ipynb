# %% [markdown]
# **1) Desarrolle el siguiente ajuste al anterior codigo**
#
# ```
# Clase Persona
# > Atributos
# - Nombre
# - Apellido
# - Edad
# ```
# ```
# Clase Profesor
# > Hereda de : Persona
# > Atributos
# - Antiguedad
# - Tutorias
# - Telefono
# ```
# ```
# Clase Investigador
# > Hereda de: Persona
# > Atributos
# - Especialidad
# - Años
# ```
# ```
# Clase ProfesorUniversitario
# > Hereda de: Persona y de Investigador
# > Atributos
# - Universidad
# - Departamento
# ```
#
# **por ultimo el desarrollo me tiene que entregar**
# ```
# >Nombre
# >Apellido
# >Edad
# >Antiguedad
# >Tutorias
# >Telefono
# >Especialidad
# >Años
# >Universidad
# >Departamento
# ```

# %%
class Persona():
  def __init__(self):
    self.__Nombre=""
    self.__Apellido=""
    self.__Edad=0

  def GetNombre(self):
    return self.__Nombre

  def SetNombre(self, nombre):
    self.__Nombre=nombre
  
  def GetApellido(self):
    return self.__Apellido

  def SetApellido(self, apellido):
    self.__Apellido = apellido

  def GetEdad(self):
    return self.__Edad

  def SetEdad(self, edad):
    self.__Edad=edad

  
class Alumno(Persona):
  def __init__(self):
    self.__Curso=""
    self.__Asignatura=""

  def GetCurso(self):
    return self.__Curso

  def SetCurso(self, curso):
    self.__Curso= curso

  def GetAsignatura(self):
    return self.__Asignatura
  
  def SetAsignatura(self, asignatura):
    self.__Asignatura = asignatura 

  def MostrarAlumno(self):
    print("alumno: ")
    print("\tNombre:",self.GetNombre())
    print("\tApellido:",self.GetApellido())
    print("\tEdad:",self.GetEdad())
    print("\tCurso:",self.__Curso)
    print("\tAsignatura:",self.__Asignatura)
    

alumno=Alumno()
alumno.SetNombre("Luis")
alumno.SetApellido("Montaña")
alumno.SetEdad("17")
alumno.SetCurso("Bachillerato")
alumno.SetAsignatura(["Matematicas","Tecnologia"])
alumno.MostrarAlumno()

# %%
class Profesor(Persona):
  def __init__(self):
    self.__Antiguedad=""
    self.__Tutorias=""
    self.__Telefono=""

  def GetAntiguedad(self):
    return self.__Antiguedad

  def SetAntiguedad(self, antiguedad):
    self.__Antiguedad = antiguedad

  def GetTutorias(self):
    return self.__Tutorias

  def SetTutorias(self, tutorias):
    self.__Tutorias = tutorias

  def GetTelefono(self):
    return self.__Telefono

  def SetTelefono(self, telefono):
    self.__Telefono = telefono

  def MostrarProfesor(self):
    print("profesor: ")
    print("\tNombre:",self.GetNombre())
    print("\tApellido:",self.GetApellido())
    print("\tEdad:",self.GetEdad())
    print("\tAntiguedad:",self.__Antiguedad)
    print("\tTutorias:",self.__Tutorias)
    print("\tTelefono:",self.__Telefono)


alumno=Alumno()
alumno.SetNombre("Luis")
alumno.SetApellido("Montaña")
alumno.SetEdad(17)
alumno.SetCurso("Bachillerato")
alumno.SetAsignatura(["Matematicas","Tecnologia"])
alumno.MostrarAlumno()


profesor=Profesor()
profesor.SetNombre("Maria")
profesor.SetApellido("Tereza Garcia")
profesor.SetEdad(40)
profesor.SetAntiguedad(20)
profesor.SetTutorias([["Lunes","2-4 pm"],["Martes","4-6 pm"]])
profesor.SetTelefono("3124500000")
profesor.MostrarProfesor()

# %%
class Investigador(Persona):
  def __init__(self):
    self.__Especialidad=""
    self.__Años=""

  def GetEspecialidad(self):
    return self.__Especialidad

  def SetEspecialidad(self, especialidad):
    self.__Especialidad = especialidad

  def GetAños(self):
    return self.__Años

  def SetAños(self, años):
    self.__Años = años


  def MostrarInvestigador(self):
    print("investigador: ")
    print("\tNombre:",self.GetNombre())
    print("\tApellido:",self.GetApellido())
    print("\tEdad:",self.GetEdad())
    print("\tEspecialidad:",self.GetEspecialidad())
    print("\tAños:",self.GetAños())


alumno=Alumno()
alumno.SetNombre("Luis")
alumno.SetApellido("Montaña")
alumno.SetEdad(17)
alumno.SetCurso("Bachillerato")
alumno.SetAsignatura(["Matematicas","Tecnologia"])
alumno.MostrarAlumno()


profesor=Profesor()
profesor.SetNombre("Maria")
profesor.SetApellido("Tereza Garcia")
profesor.SetEdad(40)
profesor.SetAntiguedad(20)
profesor.SetTutorias([["Lunes","2-4 pm"],["Martes","4-6 pm"]])
profesor.SetTelefono("3124500000")
profesor.MostrarProfesor()


investigador=Investigador()
investigador.SetNombre("Santiago")
investigador.SetApellido("Rivas Ocampos")
investigador.SetEdad(30)
investigador.SetEspecialidad("Investigar Delitos")
investigador.SetAños(5)
investigador.MostrarInvestigador()

# %%
class ProfesorUniversitario(Investigador,Persona):
  def __init__(self):
    self.__Universidad=""
    self.__Departamento=""

  def GetUniversidad(self):
    return self.__Universidad

  def SetUniversidad(self, universidad):
    self.__Universidad = universidad

  def GetDepartamento(self):
    return self.__Departamento

  def SetDepartamento(self, departamento):
    self.__Departamento = departamento
    
    
  def MostrarProfesorUniversitario(self):
    print("profesoruniversitario: ")
    print("\tNombre:",self.GetNombre())
    print("\tApellido:",self.GetApellido())
    print("\tEdad:",self.GetEdad())
    print("\tEspecialidad:",self.GetEspecialidad())
    print("\tAños:",self.GetAños())
    print("\tUniversidad:",self.GetUniversidad())
    print("\tDepartamento:",self.GetDepartamento())


profesor=Profesor()
profesor.SetNombre("Maria")
profesor.SetApellido("Tereza Garcia")
profesor.SetEdad(40)
profesor.SetAntiguedad(20)
profesor.SetTutorias([["Lunes","2-4 pm"],["Martes","4-6 pm"]])
profesor.SetTelefono("3124500000")
profesor.MostrarProfesor()


investigador=Investigador()
investigador.SetNombre("Santiago")
investigador.SetApellido("Rivas Ocampos")
investigador.SetEdad(30)
investigador.SetEspecialidad("Investigar Delitos")
investigador.SetAños(5)
investigador.MostrarInvestigador()


profesoruniversitario=ProfesorUniversitario()
profesoruniversitario.SetNombre("William")
profesoruniversitario.SetApellido("Fernando Torres")
profesoruniversitario.SetEdad(38)
profesoruniversitario.SetEspecialidad(38)
profesoruniversitario.SetAños(38)
profesoruniversitario.SetUniversidad("Escuela Tecnológica De Neiva FET")
profesoruniversitario.SetDepartamento("Huila")
profesoruniversitario.MostrarProfesorUniversitario()

# %% [markdown]
# **2) Construya el diagrama de clases del anterior punto utilizando la herramienta vista**

# %% [markdown]
# ![Diagrama de clases.drawio (1).png](data:image/png;base64,...)

# %%
class Persona:
  def __init__(self):
    self.nombre=input("ingrese su nombre")
    self.apellido=input("ingrese su apellido")
    self.edad=int(input("ingrese su edad"))
    self.cedula=int(input("ingrese su cedula"))

  def mostrar(self):
    print(self.nombre,self.apellido,self.edad,self.cedula)


class Empleado(Persona):
  def __init__(self):
    super().__init__()
    self.sueldo=float(input("ingrese su sueldo"))
 
  def mostrar(self):
    super().mostrar()
    print(self.sueldo)

  def pagar(self):
    if self.sueldo>500000:
      print("su saldo es de",self.sueldo)
    else:
      return "{} su saldo es de {} por lo tanto no recibira el pago".format(self.nombre, self.sueldo)

class Direccion:
  def mostrardireccion(self):
    print("calle 5 numero 13-32 barrio x")

class RecursosHumanos(Empleado, Direccion):
  def saludos(self):
    super().mostrardireccion()
    return "{} {} recuerde que su saldo es de pago es de {}".format(self.nombre,self.apellido,self.sueldo)


persona=RecursosHumanos()
persona.saludos()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **3) Construya el codigo que ejecute el siguiente diagrama de clase**
#
# ![Sin título.drawio.png](data:image/png;base64,...)

# %%
class Animal:
  def __init__(self):
    self.Color=input("Color del animal: ")
    self.Peso=input("Peso del animal: ")
  def comer(self):
    print("El animal esta comiendo")
  def moverse(self):
    print("El animal se esta moviendo")


class Perro(Animal):
  def __init__(self):
    super().__init__()
    self.Raza=input("Raza del perro: ")
  def ladrar(self):
      print("El perro🐶 es de color {}, con un peso de {}, es de raza {} y está ladrando.".format(self.Color,self.Peso,self.Raza))


class Ave(Animal):
  def __init__(self):
    super().__init__()
    self.Tipo=input("Tipo de ave: ")
  def Volar(self):
      print("El ave🐦 es de color {}, con un peso de {}, es de tipo {} y está volando.".format(self.Color,self.Peso,self.Tipo))
objeto=Perro()
objeto.ladrar()

# %% [markdown]
# **4) Desarrolle dos ejercicios en donde vea involucrado Poliformismo**

# %%
class BadBunny():
  def dioses_de_la_musica(self):
      print("Bad Bunny🐰 del 2020 es el verdadero Dios del Reggaeton")
class JhayCortez():
  def dioses_de_la_musica(self):
      print("Jhay Cortez🦇 del 2021 es el inigualable Dios del Chanteo")
class Anuel():
  def dioses_de_la_musica(self):
      print("Anuel👺 del 2016 es el único y real Dios del Trap")
def cantante(identidad):
  identidad.dioses_de_la_musica()
cantante(Anuel())

# %%
class BobEsponja():
  def manejar(self):
      print("Bob Esponja🧽 maneja un Bugatti Chiron para ir al Crustáceo Cascarudo")
class PatricioEstrella():
  def manejar(self):
      print("Patricio Estrella🌟 maneja una Ducati Panigale para ir a su Casa")
class Calamardo():
  def manejar(self):
      print("Calamardo🦑 maneja una Kawasaki Ninja ZX-10R para ir al Teatro")
def transporte(personaje):
  personaje.manejar()

transporte(PatricioEstrella())
